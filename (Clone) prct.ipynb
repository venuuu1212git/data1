# %%
Gprint("helo")

# %%
# Create a simple DataFrame
data = [("Alice", 25), ("Bob", 30), ("Charlie", 35)]
df = spark.createDataFrame(data, ["Name", "Age"])
 
# Show the DataFrame
df.show()
 
# Do a simple transformation
df.filter(df.Age > 28).show()

# %%
df=spark.table("workspace.default.bigg")

# %%
df.limit(2).display()

# %%
# %sql
select * from biggie;

# %%
print("1")

# %%
from pyspark.sql.functions import *

result_df = df.groupby('Item_Type').agg(
    avg('Item_MRP')
)
display(result_df)
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
df.groupBy('Item_Type').agg(
    avg('Item_MRP')
).display()

# %%
display(df.limit(10))

# %%
from pyspark.sql.functions import *
df.withColumn("FLAG",lit(" ")).display()

# %% [markdown]
# ###to multiply

# %%
df.withColumn("mul",col("Item_MRP")*col("Item_Weight")).display()

# %% [markdown]
# Typecasting

# %%
# from pyspark.sql.functions import *
# from pyspark.sql.types import *
df.withColumn("Item_Weight", col("Item_Weight").cast(StringType())).display()

# %%
a=df.sort(col("Item_Weight").asc())
a.dropna('any').display()

# %% [markdown]
# to drop duplicates

# %%
df.dropDuplicates(subset=["Item_Weight"]).display()

# %% [markdown]
# ##joins

# %%
df=spark.table("workspace.default.bigg")
